# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
dataset = pd.read_csv("D:\\Internship_June2025\\AllData\\Cancer.csv")
dataset
# Out:
#       Age  Gender        BMI  Smoking  GeneticRisk  PhysicalActivity  \
# 0      58       1  16.085313        0            1          8.146251
# 1      71       0  30.828784        0            1          9.361630
# 2      48       1  38.785084        0            2          5.135179
# 3      34       0  30.040295        0            0          9.502792
# 4      62       1  35.479721        0            0          5.356890
# ...   ...     ...        ...      ...          ...               ...
# 1495   62       1  25.090025        0            0          9.892167
# 1496   31       0  33.447125        0            1          1.668297
# 1497   63       1  32.613861        1            1          0.466848
# 1498   55       0  25.568216        0            0          7.795317
# 1499   67       1  23.663104        0            0          2.525860
#
#       AlcoholIntake  CancerHistory  Diagnosis
# 0          4.148219              1          1
# ...

# %%
dataset.shape
# Out:
# (1500, 9)

# %%
dataset.info(_)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1500 non-null   int64
#  1   Gender            1500 non-null   int64
#  2   BMI               1500 non-null   float64
#  3   Smoking           1500 non-null   int64
#  4   GeneticRisk       1500 non-null   int64
#  5   PhysicalActivity  1500 non-null   float64
#  6   AlcoholIntake     1500 non-null   float64
#  7   CancerHistory     1500 non-null   int64
#  8   Diagnosis         1500 non-null   int64
# dtypes: float64(3), int64(6)
# memory usage: 105.6 KB

# %%
dataset.isnull()
# Out:
#         Age  Gender    BMI  Smoking  GeneticRisk  PhysicalActivity  \
# 0     False   False  False    False        False             False
# 1     False   False  False    False        False             False
# 2     False   False  False    False        False             False
# 3     False   False  False    False        False             False
# 4     False   False  False    False        False             False
# ...     ...     ...    ...      ...          ...               ...
# 1495  False   False  False    False        False             False
# 1496  False   False  False    False        False             False
# 1497  False   False  False    False        False             False
# 1498  False   False  False    False        False             False
# 1499  False   False  False    False        False             False
#
#       AlcoholIntake  CancerHistory  Diagnosis
# 0             False          False      False
# 1             False          False      False
# ...

# %%
dataset.notnull()
# Out:
#        Age  Gender   BMI  Smoking  GeneticRisk  PhysicalActivity  \
# 0     True    True  True     True         True              True
# 1     True    True  True     True         True              True
# 2     True    True  True     True         True              True
# 3     True    True  True     True         True              True
# 4     True    True  True     True         True              True
# ...    ...     ...   ...      ...          ...               ...
# 1495  True    True  True     True         True              True
# 1496  True    True  True     True         True              True
# 1497  True    True  True     True         True              True
# 1498  True    True  True     True         True              True
# 1499  True    True  True     True         True              True
#
#       AlcoholIntake  CancerHistory  Diagnosis
# 0              True           True       True
# 1              True           True       True
# ...

# %%
x = dataset["Gender"]
y = dataset["GeneticRisk"]
plt.plot(x,y,marker='*',ms=20,mec='#27f5f5',mfc='g',color='b',ls='--',linewidth=2)  #marker size   #marker edge color
# plt.grid(color="y",ls='-.')
plt.show()

# %%
x = dataset["Gender"]
y = dataset["GeneticRisk"]
plt.plot(x,y)
plt.grid()
plt.show()

# %%
x = dataset["Gender"]
y = dataset["GeneticRisk"]
plt.plot(x,y,'*')
plt.grid()
plt.show()

# %%
x = dataset["Gender"]
y = dataset["GeneticRisk"]
plt.plot(x,y,'s--r')
plt.grid()
plt.show(_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8424\3922033518.py in ?()
#       1 x = dataset["Gender"]
#       2 y = dataset["GeneticRisk"]
#       3 plt.plot(x,y,'s--r')
#       4 plt.grid()
# ----> 5 plt.show(_)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py in ?(*args, **kwargs)
#     610     the end of every cell by default. Thus, you usually don't have to call it
#     611     explicitly there.
#     612     """
#     613     _warn_if_gui_out_of_main_thread()
# --> 614     return _get_backend_mod().show(*args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib_inline\backend_inline.py in ?(close, block)
#      94     finally:
#      95         show._to_draw = []
#      96         # only call close('all') if any to close
# ...

# %%
x = np.array([58,44,55,77,78,43])
y = np.array([38,45,67,22,45,45])
plt.plot(x,y,marker='*',ms=20,mec='b',mfc='y',color='red')  #marker size   #marker edge color
plt.grid(color="black")
plt.show()

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([10,25,20,65,45,100])

f1 = {'family':'serif','color':'red','size':15}
f2 = {'family':'Times New Roman','color':'b','size':20}
f3 = {'family':'serif','color':'y','size':10}
#plot1 -lable
plt.title(" Cancar ratio",fontdict=f2,loc='left')
plt.xlabel("age",fontdict=f1)
plt.ylabel("BMI",fontdict=f3)

#plot2
a = np.array([1,2,3,4,5,6])
b = np.array([15,35,21,75,55,150])

#plot2 -lable
plt.title("",fontdict=f1,loc='left')
plt.xlabel("",fontdict=f2)
plt.ylabel(",fontdict=f3)

plt.plot(x,y,a,b)
plt.grid(color='hotpink')
plt.show()
