# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y)
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y)
plt.grid()
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,'*')
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,'p')
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,'s--r')
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,'p--r')
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,'p--g')
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,marker='D')
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,marker='H')
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,marker='*',ms=20)  #marker size
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,marker='*',ms=20,mec='r')  #marker size
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,marker='*',ms=20,mec='b',mfc='y',color='red')  #marker size   #marker edge color
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,marker='*',ms=20,mec='b',mfc='y',color='red')  #marker size   #marker edge color
plt.grid(color="black")
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,marker='*',ms=20,mec='b',mfc='#27f5f5',color='#f527a9')  #marker size   #marker edge color
plt.grid(color="black")
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,marker='*',ms=20,mec='b',mfc='#27f5f5',color='#f527a9',ls='-.')  #marker size   #marker edge color
plt.grid(color="black")
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,marker='*',ms=20,mec='b',mfc='#27f5f5',color='#f527a9',ls=':')  #marker size   #marker edge color
plt.grid(color="black")
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,marker='*',ms=20,mec='b',mfc='#27f5f5',color='black',ls=':')  #marker size   #marker edge color
plt.grid(color="black")
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,50,80,150,200])
plt.plot(x,y,marker='*',ms=20,mec='#27f5f5',mfc='g',color='b',ls='--',linewidth=2)  #marker size   #marker edge color
plt.grid(color="y",ls='-.')
plt.show()

# %%
x = np.array([1,2,5,7,9])
y = np.array([10,25,80,150,200])
plt.plot(x,y,'o')
plt.show()

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([10,25,20,65,45,100])
plt.xlabel("year of experience")
plt.xlabel("salary of emp in k")
plt.plot(x,y,'o')
plt.show()

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([10,25,20,65,45,100])
plt.xlabel("year of experience")
plt.xlabel("salary of emp in k")
plt.title("salary pridiction")
plt.plot(x,y,'o')
plt.show()

# %%
x = np.array([1,2,3,4,5,6])
y = np.array([10,25,20,65,45,100])
f1 = {'family':'serif','color':'red','size':15}
f2 = {'family':'Times New Roman','color':'b','size':20}
f3 = {'family':'serif','color':'y','size':10}

plt.title("salary prediction",fontdict=f2,loc='left')
plt.xlabel("year of experience",fontdict=f1)
plt.xlabel("salary of emp in k",fontdict=f3)
plt.plot(x,y,'o')
plt.show()

# %%
#plot1
x = np.array([1,2,3,4,5,6])
y = np.array([10,25,20,65,45,100])

f1 = {'family':'serif','color':'red','size':15}
f2 = {'family':'Times New Roman','color':'b','size':20}
f3 = {'family':'serif','color':'y','size':10}
#plot1 -lable
plt.title("IIT salary prediction",fontdict=f2,loc='left')
plt.xlabel("year of experience",fontdict=f1)
plt.ylabel("salary of emp in k",fontdict=f3)

#plot2
a = np.array([1,2,3,4,5,6])
b = np.array([15,35,21,75,55,150])

#plot2 -lable
plt.title("Racksonsit salary prediction",fontdict=f1,loc='left')
plt.xlabel("year of experience",fontdict=f2)
plt.ylabel("salary of emp in k",fontdict=f3)

plt.plot(x,y,a,b)
plt.grid(color='hotpink')
plt.show()

# %%
plt.rcParams["figure.figsize"]=(10,3)
#plot1
x = np.array([1,2,3,4,5,6])
y = np.array([10,25,20,65,45,100])
plt.subplot(1,3,1)
plt.plot(x,y,marker="+",mec="green",mfc="y",ms=20)

#plot1 -lable
plt.title("IIT salary prediction")

#plot2
a = np.array([1,2,3,4,5,6])
b = np.array([10,25,20,65,45,100])

plt.subplot(1,3,2)
plt.plot(x,y,marker="H",mec="yellow",mfc="r",ms=12)

plt.title("IIM salary prediction")

#plot3
m = np.array([1,2,3,4,5,6])
n = np.array([10,25,20,65,45,100])

plt.subplot(1,3,3)
plt.plot(x,y,marker="P",mec="yellow",mfc="r",ms=12)

plt.title("VIT salary prediction")
plt.plot(x,y,a,b)
plt.grid(color='hotpink')
plt.show()

# %%
#part3 : legends grid axis and lables

# %%
days = [1,2,3,4,5,6,7]
max_t = [50,51,52,48,47,49,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]

plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")

# %%
days = [1,2,3,4,5,6,7]
max_t = [50,51,52,48,47,49,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("Weather")
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")
plt.legend(loc="best")

# %%
days = [1,2,3,4,5,6,7]
max_t = [50,51,52,48,47,49,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("Weather")
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")
plt.legend(loc='lower right',shadow=True,fontsize='large')

# %%
days = [1,2,3,4,5,6,7]
max_t = [50,51,52,48,47,49,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]
plt.xlabel("Day")
plt.ylabel("Temperature")
plt.title("Weather")
plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="avg")
plt.legend(loc='upper right',shadow=True,fontsize='large')

# %%
# Bar chart

# %%
company = ['Google','Amzn','Msft','FB']
revenue = [90,136,89,27]
xpos = np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.bar(xpos,revenue,label='Revenue')
plt.xticks(xpos,company)
plt.ylabel("revenue(Bln)")
plt.title("Technology stocks of Market")
plt.legend()

# %%
profit = [40,2,34,12]

# %%
plt.bar(xpos-0.2,revenue,width=0.4,label='Revenue')
plt.bar(xpos+0.2,profit,width=0.4,label='profit')
plt.xticks(xpos,company)
plt.ylabel("revenue(Bln)")
plt.title("Technology stocks of Market")
plt.legend()

# %%
plt.barh(xpos,revenue,label='Revenue')
plt.xticks(xpos,company)
plt.ylabel("revenue(Bln)")
plt.title("Technology stocks of Market")
plt.legend()

# %%
plt.rcParams["figure.figsize"]=(10,3)
#plot1
x = np.array([1,2,3,4,5,6])
y = np.array([10,25,20,65,45,100])
plt.subplot(1,3,1)
plt.plot(x,y,marker="*",mec="green",mfc="y",ms=20)

#plot1 -lable
plt.title("MI score prediction")

#plot2
a = np.array([1,2,3,4,5,6])
b = np.array([10,25,20,65,45,100])

plt.subplot(1,3,2)
plt.plot(x,y,marker="H",mec="yellow",mfc="r",ms=12)

plt.title("MI wicket prediction")

#plot3
m = np.array([1,2,3,4,5,6])
n = np.array([10,25,20,65,45,100])

plt.subplot(1,3,3)
plt.plot(x,y,marker="P",mec="yellow",mfc="b",ms=12)

plt.title("MI runrate prediction")
# plt.plot(x,y,a,b)
# plt.grid(color='hotpink')
plt.show()

# %%
#plot1
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
x = np.array([2001,2002,2003,2004,2005,2006])
y = np.array([2100,4800,3000,10005,9000,18000])

y_axis = np.array([2000, 3000, 4000, 5000, 6000, 7000])

f1 = {'family':'serif','color':'red','size':15}
f2 = {'family':'Times New Roman','color':'b','size':18}
f3 = {'family':'serif','color':'b','size':15}
#plot1 -lable
plt.title("MI win prediction",fontdict=f2,loc='left')
plt.xlabel("year",fontdict=f1)
plt.ylabel(" close prices",fontdict=f3)

#plot2
a = np.array([2001,2002,2003,2004,2005,2006])
b = np.array([2000,4500,3200,9500,15000,18000])
y_axis = np.array([2000,3000,4000,5000,6000,7000])
y_axis = "close prices()"
plt.ylim([2000,18000])
#plot2 -lable
plt.title("MI win prediction",fontdict=f1,loc='left')
plt.xlabel("year",fontdict=f2)
plt.ylabel(" close prices",fontdict=f3)

plt.plot(x,y,a,b)
plt.grid(color='hotpink')
plt.show()
