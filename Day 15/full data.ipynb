# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('full_data.csv')
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
df['stroke'].value_counts()
# Out:
# stroke
# 0    4733
# 1     248
# Name: count, dtype: int64

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4976    Male  41.0             0              0           No        Private
# 4977    Male  40.0             0              0          Yes        Private
# 4978  Female  45.0             1              0          Yes       Govt_job
# 4979    Male  40.0             0              0          Yes        Private
# 4980  Female  80.0             1              0          Yes        Private
#
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4976    0
# 4977    0
# 4978    0
# 4979    0
# 4980    0
# Name: stroke, Length: 4981, dtype: int64

# %%
# using map function we encoding the data 
x['gender'].map({'Male':1,"female":0})
# Out:
# 0       1.0
# 1       1.0
# 2       NaN
# 3       NaN
# 4       1.0
#        ...
# 4976    1.0
# 4977    1.0
# 4978    NaN
# 4979    1.0
# 4980    NaN
# Name: gender, Length: 4981, dtype: float64

# %%
# using label encoding we can convert categorical data into numerical 
from sklearn.preprocessing import LabelEncoder
l1 = LabelEncoder()

# %%
x['genderr'] = l1.fit_transform(x['gender'])
x['ever_married'] = l1.fit_transform(x['ever_married'])
x['work_type'] = l1.fit_transform(x['work_type'])
x['Residence_type'] = l1.fit_transform(x['Residence_type'])
x['smoking_status'] = l1.fit_transform(x['smoking_status'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x['genderr'] = l1.fit_transform(x['gender'])
#       2 x['ever_married'] = l1.fit_transform(x['ever_married'])
#       3 x['work_type'] = l1.fit_transform(x['work_type'])
#
# NameError: name 'x' is not defined

# %%
from imblearn.under_sampling import NearMiss
ab = NearMiss()
x_res,y_res = ab.fit_resample(x,y)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from imblearn.under_sampling import NearMiss
#       2 ab = NearMiss()
#       3 x_res,y_res = ab.fit_resample(x,y)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)  # Converts 'Male'/'Female' into numbers

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=35)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=35)
#
# NameError: name 'x' is not defined
