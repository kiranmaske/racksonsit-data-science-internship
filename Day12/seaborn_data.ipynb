# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# data load
sns.set(style='darkgrid')
tips = sns.load_dataset('titanic')
tips
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tips['age']>25
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: age, Length: 891, dtype: bool

# %%
tips.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
tips['deck'].unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips)

# %%
sns.relplot(x ='smoker',y ='day',data=tips)

# %%
sns.relplot(x ='tip',y ='day',data=tips)

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,style='sex')

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,style='sex',size='smoker')

# %%
# part2

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x ='total_bill',y ='sex',data=tips)

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips)

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,style='sex',hue='smoker')

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,style='day',hue='smoker')

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,size='smoker',color='red')

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,size='day',style='sex')

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,hue='sex')

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,hue='day')

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,hue='day',style='time')

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,hue='day',style='smoker')

# %%
tp = sns.load_dataset('titanic')
tp
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.relplot(x='age',y='fare',col='who',data=tp)

# %%
tips=sns.load_dataset('tips')

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,hue='sex',col='smoker')

# %%
sns.relplot(x ='total_bill',y ='tip',data=tips,hue='sex',col='day')

# %%
df=pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data = df.loc[(df['sex']=='female')&(df['smoker']=='yes')|((df['charges']==5000)&(df['charges']==25000))]
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 58     53  female  22.880         1    yes  southeast  23244.79020
# 64     20  female  22.420         0    yes  northwest  14711.74380
# ...   ...     ...     ...       ...    ...        ...          ...
# 1308   25  female  30.200         0    yes  southwest  33900.65300
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1314   30  female  23.655         3    yes  northwest  18765.87545
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [115 rows x 7 columns]

# %%
sns.countplot(x='region',data=data)
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
sns.relplot( x ='age', y ='charges',data=data,hue='region')

# %%
df=pd.read_csv('insurance1.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.relplot( x ='charges', y ='age',data=df,hue='sex',col='smoker')

# %%
sns.relplot( x ='bmi', y ='age',data=df,hue='smoker',col='sex')

# %%
# Part3

# %%
df = pd.read_csv('Test.csv')
df
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK     SQUARE_FT  \
# 0         Owner                   0     0        1       BHK    545.171340
# 1        Dealer                   1     1        2       BHK    800.000000
# 2        Dealer                   0     0        2       BHK   1257.096513
# 3        Dealer                   0     0        3       BHK   1400.329489
# 4         Owner                   0     0        1       BHK    430.477830
# ...         ...                 ...   ...      ...       ...           ...
# 68715    Dealer                   0     1        2       BHK    856.555505
# 68716    Dealer                   0     1        3       BHK   2304.147465
# 68717    Dealer                   1     1        1       BHK  33362.792750
# 68718    Dealer                   0     0        2       BHK   1173.708920
# 68719    Dealer                   0     0        3       BHK   2439.532944
#
# ...

# %%
df['POSTED_BY'].unique()
# Out:
# array(['Owner', 'Dealer', 'Builder'], dtype=object)

# %%
df['POSTED_BY'].value_counts()
# Out:
# POSTED_BY
# Dealer     42437
# Owner      24920
# Builder     1363
# Name: count, dtype: int64

# %%
sns.countplot(x='BHK_OR_RK',data=df)
# Out:
# <Axes: xlabel='BHK_OR_RK', ylabel='count'>

# %%
sns.countplot(x='POSTED_BY',data=df)
# Out:
# <Axes: xlabel='POSTED_BY', ylabel='count'>

# %%
sns.countplot(x='BHK_NO.',data=df,hue="POSTED_BY")
# Out:
# <Axes: xlabel='BHK_NO.', ylabel='count'>

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(x='sex',data=titanic,hue="pclass")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# find count of alive male and female traveled in 1st and 3rd class

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
data1 = titanic.loc[(titanic['alive']=='yes')&((titanic['sex']=='male')|(titanic['sex']=='female'))&(
    (titanic['class']=='First')|(titanic['class']=='Third'))]

# %%
data = titanic.loc[(titanic['alive']=='yes')&((titanic['sex']=='male')|(titanic['sex']=='female'))&(
    (titanic['who']=='women')|(titanic['who']=='child'))]

# %%
data['who'].value_counts()
# Out:
# who
# child    49
# Name: count, dtype: int64

# %%
data['alive'].value_counts()
# Out:
# alive
# yes    49
# Name: count, dtype: int64

# %%
sns.countplot(x='sex',data=data1,hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#part 4
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(data=titanic,x='age',y='class')

# %%
sns.catplot(data=titanic,x='class',y='age',kind='swarm')
# Out:
# C:\Users\Kiran Maske\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 7.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Kiran Maske\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 20.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Kiran Maske\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 18.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=titanic,x='class',y='age',kind='box')

# %%
df = pd.read_csv("covid_19_india.csv")
df
# Out:
#          Sno        Date     Time State/UnionTerritory  \
# 0          1  2020-01-30  6:00 PM               Kerala
# 1          2  2020-01-31  6:00 PM               Kerala
# 2          3  2020-02-01  6:00 PM               Kerala
# 3          4  2020-02-02  6:00 PM               Kerala
# 4          5  2020-02-03  6:00 PM               Kerala
# ...      ...         ...      ...                  ...
# 18105  18106  2021-08-11  8:00 AM            Telangana
# 18106  18107  2021-08-11  8:00 AM              Tripura
# 18107  18108  2021-08-11  8:00 AM          Uttarakhand
# 18108  18109  2021-08-11  8:00 AM        Uttar Pradesh
# 18109  18110  2021-08-11  8:00 AM          West Bengal
#
#       ConfirmedIndianNational ConfirmedForeignNational    Cured  Deaths  \
# 0                           1                        0        0       0
# 1                           1                        0        0       0
# 2                           2                        0        0       0
# ...

# %%
df.isnull()
# Out:
#          Sno   Date   Time  State/UnionTerritory  ConfirmedIndianNational  \
# 0      False  False  False                 False                    False
# 1      False  False  False                 False                    False
# 2      False  False  False                 False                    False
# 3      False  False  False                 False                    False
# 4      False  False  False                 False                    False
# ...      ...    ...    ...                   ...                      ...
# 18105  False  False  False                 False                    False
# 18106  False  False  False                 False                    False
# 18107  False  False  False                 False                    False
# 18108  False  False  False                 False                    False
# 18109  False  False  False                 False                    False
#
#        ConfirmedForeignNational  Cured  Deaths  Confirmed
# ...

# %%
df["State/UnionTerritory"].unique()
# Out:
# array(['Kerala', 'Telengana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'West Bengal', 'Chhattisgarh',
#        'Chandigarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Andaman and Nicobar Islands',
#        'Goa', 'Unassigned', 'Assam', 'Jharkhand', 'Arunachal Pradesh',
#        'Tripura', 'Nagaland', 'Meghalaya',
#        'Dadra and Nagar Haveli and Daman and Diu',
#        'Cases being reassigned to states', 'Sikkim', 'Daman & Diu',
#        'Lakshadweep', 'Telangana', 'Dadra and Nagar Haveli', 'Bihar****',
#        'Madhya Pradesh***', 'Himanchal Pradesh', 'Karanataka',
#        'Maharashtra***'], dtype=object)

# %%
df["State/UnionTerritory"]=df["State/UnionTerritory"].replace('Madhya Pradesh***',"Madhya Pradesh

# %%
start = "2020-01-01"
end = "2020-12-31"
data = pd.date_range(start,end)
data
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', length=366, freq='D')

# %%
start = "2020-01-01"
end = "2020-12-31"
data = df.loc[(df['Date,
data

# %%
data1 = data.loc[df["State/UnionTerritory"]=="Maharastra"]
data1.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 data1 = data.loc[df["State/UnionTerritory"]=="Maharastra"]
#       2 data1.shape
#
# AttributeError: 'DatetimeIndex' object has no attribute 'loc'

# %%
data2 = data.loc[(df["State/UnionTerritory"]=="Maharashtra")|(df["State/UnionTerritory"]=="Telengana")|(df["State/UnionTerritory"]=="Kerala")]
data2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 data2 = data.loc[(df["State/UnionTerritory"]=="Maharashtra")|(df["State/UnionTerritory"]=="Telengana")|(df["State/UnionTerritory"]=="Kerala")]
#       2 data2
#
# AttributeError: 'DatetimeIndex' object has no attribute 'loc'

# %%
sns.countplot(data=data2,x="State/UnionTerritory")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 sns.countplot(data=data2,x="State/UnionTerritory")
#
# NameError: name 'data2' is not defined

# %%
sns.catplot(data=data2,x="State/UnionTerritory",y=")
