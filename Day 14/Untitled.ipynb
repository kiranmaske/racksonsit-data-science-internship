# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Cancer.csv')
dataset
# Out:
#       Age  Gender        BMI  Smoking  GeneticRisk  PhysicalActivity  \
# 0      58       1  16.085313        0            1          8.146251
# 1      71       0  30.828784        0            1          9.361630
# 2      48       1  38.785084        0            2          5.135179
# 3      34       0  30.040295        0            0          9.502792
# 4      62       1  35.479721        0            0          5.356890
# ...   ...     ...        ...      ...          ...               ...
# 1495   62       1  25.090025        0            0          9.892167
# 1496   31       0  33.447125        0            1          1.668297
# 1497   63       1  32.613861        1            1          0.466848
# 1498   55       0  25.568216        0            0          7.795317
# 1499   67       1  23.663104        0            0          2.525860
#
#       AlcoholIntake  CancerHistory  Diagnosis
# 0          4.148219              1          1
# ...

# %%
score = reg.score(x_train,y_train)
score
# Out:
# 1.0

# %%
x = dataset.iloc[:,[0,1,2,3,4,5,6,7,8]].values
y = dataset.iloc[:,2].values

# %%
x
# Out:
# array([[58.        ,  1.        , 16.08531332, ...,  4.14821903,
#          1.        ,  1.        ],
#        [71.        ,  0.        , 30.82878439, ...,  3.51968333,
#          0.        ,  0.        ],
#        [48.        ,  1.        , 38.78508356, ...,  4.72836769,
#          0.        ,  1.        ],
#        ...,
#        [63.        ,  1.        , 32.6138607 , ...,  0.15010113,
#          0.        ,  1.        ],
#        [55.        ,  0.        , 25.56821592, ...,  1.98613765,
#          1.        ,  1.        ],
#        [67.        ,  1.        , 23.6631042 , ...,  2.85660008,
#          1.        ,  0.        ]], shape=(1500, 9))

# %%
y
# Out:
# array([16.08531332, 30.82878439, 38.78508356, ..., 32.6138607 ,
#        25.56821592, 23.6631042 ], shape=(1500,))

# %%
dataset.isnull().sum()
# Out:
# Age                 0
# Gender              0
# BMI                 0
# Smoking             0
# GeneticRisk         0
# PhysicalActivity    0
# AlcoholIntake       0
# CancerHistory       0
# Diagnosis           0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
x_train
# Out:
# array([[63.        ,  1.        , 36.84246484, ...,  2.74200468,
#          0.        ,  1.        ],
#        [78.        ,  0.        , 39.87048235, ...,  3.34090331,
#          0.        ,  1.        ],
#        [68.        ,  0.        , 26.24461622, ...,  4.57308227,
#          0.        ,  0.        ],
#        ...,
#        [41.        ,  0.        , 36.76446063, ...,  1.24979491,
#          0.        ,  0.        ],
#        [76.        ,  1.        , 22.79659645, ...,  2.94735402,
#          0.        ,  0.        ],
#        [27.        ,  0.        , 16.12278247, ...,  2.92112394,
#          0.        ,  0.        ]], shape=(1200, 9))

# %%
y_train
# Out:
# array([36.84246484, 39.87048235, 26.24461622, ..., 36.76446063,
#        22.79659645, 16.12278247], shape=(1200,))

# %%
x_test
# Out:
# array([[49.        ,  1.        , 20.31610941, ...,  0.76471593,
#          0.        ,  0.        ],
#        [28.        ,  1.        , 16.73559607, ...,  1.60090584,
#          0.        ,  0.        ],
#        [76.        ,  0.        , 21.48854458, ...,  3.58315968,
#          0.        ,  1.        ],
#        ...,
#        [42.        ,  1.        , 25.8182284 , ...,  3.5930187 ,
#          1.        ,  1.        ],
#        [44.        ,  0.        , 29.01650236, ...,  2.98361495,
#          0.        ,  1.        ],
#        [78.        ,  0.        , 25.1079692 , ...,  3.65339506,
#          1.        ,  1.        ]], shape=(300, 9))

# %%
y_test
# Out:
# array([20.31610941, 16.73559607, 21.48854458, 17.54509207, 31.19543615,
#        39.19650087, 30.55858162, 28.53519018, 20.86605205, 19.92314261,
#        25.24762224, 30.19763035, 19.1437445 , 33.43392693, 20.65072495,
#        26.77919747, 25.80047319, 30.65585804, 24.78814245, 39.17588188,
#        28.66743532, 19.97480347, 28.61205832, 37.25352843, 27.41917147,
#        35.148135  , 26.35943336, 18.03466045, 29.86190838, 26.78217918,
#        35.73486662, 38.69220065, 18.80260708, 39.78319754, 19.4813903 ,
#        38.51961301, 22.06181066, 21.88452936, 29.12713281, 39.8859379 ,
#        32.85081611, 35.70623131, 28.72146663, 21.16697161, 15.47790236,
#        25.35324381, 33.85662433, 32.22213255, 20.12203185, 17.90915995,
#        29.69423402, 18.6593498 , 37.65636451, 31.72555843, 31.14527032,
#        16.7733054 , 35.88700564, 37.34974275, 17.96256559, 27.70901367,
#        36.94935801, 27.91431571, 32.37377722, 28.51984387, 16.56724054,
# ...

# %% [markdown]
# #training the simple linear regression model on traINING

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred =reg.predict(x_test)
y_pred
# Out:
# array([20.31610941, 16.73559607, 21.48854458, 17.54509207, 31.19543615,
#        39.19650087, 30.55858162, 28.53519018, 20.86605205, 19.92314261,
#        25.24762224, 30.19763035, 19.1437445 , 33.43392693, 20.65072495,
#        26.77919747, 25.80047319, 30.65585804, 24.78814245, 39.17588188,
#        28.66743532, 19.97480347, 28.61205832, 37.25352843, 27.41917147,
#        35.148135  , 26.35943336, 18.03466045, 29.86190838, 26.78217918,
#        35.73486662, 38.69220065, 18.80260708, 39.78319754, 19.4813903 ,
#        38.51961301, 22.06181066, 21.88452936, 29.12713281, 39.8859379 ,
#        32.85081611, 35.70623131, 28.72146663, 21.16697161, 15.47790236,
#        25.35324381, 33.85662433, 32.22213255, 20.12203185, 17.90915995,
#        29.69423402, 18.6593498 , 37.65636451, 31.72555843, 31.14527032,
#        16.7733054 , 35.88700564, 37.34974275, 17.96256559, 27.70901367,
#        36.94935801, 27.91431571, 32.37377722, 28.51984387, 16.56724054,
# ...

# %%
x_test
# Out:
# array([[49.        ,  1.        , 20.31610941, ...,  0.76471593,
#          0.        ,  0.        ],
#        [28.        ,  1.        , 16.73559607, ...,  1.60090584,
#          0.        ,  0.        ],
#        [76.        ,  0.        , 21.48854458, ...,  3.58315968,
#          0.        ,  1.        ],
#        ...,
#        [42.        ,  1.        , 25.8182284 , ...,  3.5930187 ,
#          1.        ,  1.        ],
#        [44.        ,  0.        , 29.01650236, ...,  2.98361495,
#          0.        ,  1.        ],
#        [78.        ,  0.        , 25.1079692 , ...,  3.65339506,
#          1.        ,  1.        ]], shape=(300, 9))

# %%
y_test
# Out:
# array([20.31610941, 16.73559607, 21.48854458, 17.54509207, 31.19543615,
#        39.19650087, 30.55858162, 28.53519018, 20.86605205, 19.92314261,
#        25.24762224, 30.19763035, 19.1437445 , 33.43392693, 20.65072495,
#        26.77919747, 25.80047319, 30.65585804, 24.78814245, 39.17588188,
#        28.66743532, 19.97480347, 28.61205832, 37.25352843, 27.41917147,
#        35.148135  , 26.35943336, 18.03466045, 29.86190838, 26.78217918,
#        35.73486662, 38.69220065, 18.80260708, 39.78319754, 19.4813903 ,
#        38.51961301, 22.06181066, 21.88452936, 29.12713281, 39.8859379 ,
#        32.85081611, 35.70623131, 28.72146663, 21.16697161, 15.47790236,
#        25.35324381, 33.85662433, 32.22213255, 20.12203185, 17.90915995,
#        29.69423402, 18.6593498 , 37.65636451, 31.72555843, 31.14527032,
#        16.7733054 , 35.88700564, 37.34974275, 17.96256559, 27.70901367,
#        36.94935801, 27.91431571, 32.37377722, 28.51984387, 16.56724054,
# ...

# %%
diff = (y_pred-y_test)
diff
# Out:
# array([-4.26325641e-14, -4.61852778e-14, -4.26325641e-14, -4.61852778e-14,
#        -1.77635684e-14, -7.10542736e-15, -2.48689958e-14, -2.48689958e-14,
#        -4.61852778e-14, -4.61852778e-14, -3.55271368e-14, -2.13162821e-14,
#        -4.26325641e-14, -2.13162821e-14, -4.26325641e-14, -3.19744231e-14,
#        -3.19744231e-14, -2.48689958e-14, -3.90798505e-14, -7.10542736e-15,
#        -2.84217094e-14, -4.61852778e-14, -2.84217094e-14, -1.42108547e-14,
#        -3.19744231e-14, -1.42108547e-14, -3.19744231e-14, -4.61852778e-14,
#        -2.84217094e-14, -3.19744231e-14, -2.13162821e-14, -7.10542736e-15,
#        -4.61852778e-14, -7.10542736e-15, -4.61852778e-14, -7.10542736e-15,
#        -3.90798505e-14, -3.90798505e-14, -2.84217094e-14, -7.10542736e-15,
#        -2.13162821e-14, -1.42108547e-14, -2.84217094e-14, -3.90798505e-14,
#        -5.32907052e-14, -3.19744231e-14, -2.13162821e-14, -2.13162821e-14,
# ...

# %%
pd.DataFrame(np.c_[y_test,y_pred,diff],columns=["Actual value","predict value","Difference"])
# Out:
#      Actual value  predict value    Difference
# 0       20.316109      20.316109 -4.263256e-14
# 1       16.735596      16.735596 -4.618528e-14
# 2       21.488545      21.488545 -4.263256e-14
# 3       17.545092      17.545092 -4.618528e-14
# 4       31.195436      31.195436 -1.776357e-14
# ..            ...            ...           ...
# 295     30.621852      30.621852 -2.486900e-14
# 296     36.140109      36.140109 -1.421085e-14
# 297     25.818228      25.818228 -3.197442e-14
# 298     29.016502      29.016502 -2.842171e-14
# 299     25.107969      25.107969 -3.552714e-14
#
# [300 rows x 3 columns]

# %%
plt.scatter(x_train,y_train,color="r")
plt.plot(x_train,reg.predict(x_train),color="blue")
plt.title("Age vs BMI(Training set)")
plt.xlabel("Age")
plt.ylabel("BMI")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plt.scatter(x_train,y_train,color="r")
#       2 plt.plot(x_train,reg.predict(x_train),color="blue")
#       3 plt.title("Age vs BMI(Training set)")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (1200, 9)
# (1200,)

# %%
plt.scatter(x_train,y_train,color="r")
plt.plot(x_train,reg.predict(x_train),color="blue")
plt.title("Age vs BMI(Training set)")
plt.xlabel("Age")
plt.ylabel("BMI")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.scatter(x_train,y_train,color="r")
#       2 plt.plot(x_train,reg.predict(x_train),color="blue")
#       3 plt.title("Age vs BMI(Training set)")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
print(x_train.ndim)
print(y_train.ndim)
# Out:
# 2
# 1

# %%
plt.scatter(x_train.ravel(), y_train, color="r")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plt.scatter(x_train.ravel(), y_train, color="r")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
score = reg.score(x_train,y_train)
score
# Out:
# 1.0
