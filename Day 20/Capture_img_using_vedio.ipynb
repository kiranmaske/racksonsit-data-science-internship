# %%
import cv2
save_image = 5150

cap = cv2.VideoCapture(r"D:\Data Science All\Data Science AI ML 45 Days Training\CV_PPTS\cv_all_codes\cv_all_codes\4K Road traffic video.mp4")

# VARIABLES
sec = 0.0
framerate = 1

while True:
    try:
        _, img = cap.read()
        print("Image capture")
        sec += framerate

        n = int(input("Enter the count:"))
        for x in range(n):
            save_image += 1
            cv2.imwrite(f"D:/Data Science All/Data Science AI ML 45 Days Training/CV_PPTS/cv_all_codes/cv_all_codes/img save/cap_{save_image}.jpg",img)



    except Exception as e:
        print("Theres is exception-{}".format(e))
# Out:
# Image capture
# Enter the count: 5
# Theres is exception-OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:929: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'
#
# Image capture
